# %%
from dotenv import load_dotenv
import os

load_dotenv()

# %%
EVENT_JUDGE_MAPPING = {

  "G1-Bhajans": {
    "group": "Group 1",
    "displayName": "Bhajans",
    "eventRef": "/eventData_v2/G1-Bhajans",
    "judges": [
      "Sathyashree (ATP Alumna)",
      "Sai Brindha (ATP Alumna + Organising team)"
    ]
  },

  "G1-Slokas": {
    "group": "Group 1",
    "displayName": "Sloka Chanting",
    "eventRef": "/eventData_v2/G1-Slokas",
    "judges": [
      "Niranjan V.",
      "Priyadarshini (ATP Alumna + BV Guru)",
      "Srimathy (ATP Alumna + BV Guru)"
    ]
  },

  "G1-Vedam": {
    "group": "Group 1",
    "displayName": "Vedam",
    "eventRef": "/eventData_v2/G1-Vedam",
    "judges": [
      "Sai Narayanan",
      "Prashanth B K",
      "K Deepika Rani (School Alumna)"
    ]
  },

  "G1-Tamizhchants": {
    "group": "Group 1",
    "displayName": "Tamizh Chants",
    "eventRef": "/eventData_v2/G1-Tamizhchants",
    "judges": [
      "J Sai Laavanya (ATP Alumna + BV Guru)",
      "S Santhanalakshmi (ATP Alumna + BV Guru)"
    ]
  },

  "G1-StoryTelling-English": {
    "group": "Group 1",
    "displayName": "Story Telling (English)",
    "eventRef": "/eventData_v2/G1-StoryTelling-English",
    "judges": [
      "Harihara Krishna",
      "Kirti Chetty (ATP Alumna)",
      "Usha Srikanth (ATP Alumna + BV Guru)"
    ]
  },

  "G1-StoryTelling-Tamil": {
    "group": "Group 1",
    "displayName": "Story Telling (Tamil)",
    "eventRef": "/eventData_v2/G1-StoryTelling-Tamil",
    "judges": [
      "Sumitha Ganeshan (ATP Alumna)",
      "T D Krishnasree (ATP Alumna + BV Guru)",
      "Rajharaman"
    ]
  },

  "G1-Drawing": {
    "group": "Group 1",
    "displayName": "Drawing",
    "eventRef": "/eventData_v2/G1-Drawing",
    "judges": [
      "Mathangi Hariharan (ATP Alumna)",
      "Ranjani Srinivasan (ATP Alumna)"
    ]
  },

  "G2-Bhajans-Boys": {
    "group": "Group 2",
    "displayName": "Bhajan (Boys)",
    "eventRef": "/eventData_v2/G2-Bhajans-Boys",
    "judges": [
      "Kavitha Murali (TNS SSC)",
      "Saishree (ATP Alumna)"
    ]
  },

  "G2-Bhajans-Girls": {
    "group": "Group 2",
    "displayName": "Bhajan (Girls)",
    "eventRef": "/eventData_v2/G2-Bhajans-Girls",
    "judges": [
      "Kalpana Balasubramaniam (TNN SSC)",
      "Srividhya Natarajan (ATP Alumna + BV Guru)"
    ]
  },

  "G2-Slokas-Boys": {
    "group": "Group 2",
    "displayName": "Sloka Chanting (Boys)",
    "eventRef": "/eventData_v2/G2-Slokas-Boys",
    "judges": [
      "Sai Prasath",
      "Krithika (Madurai)"
    ]
  },

  "G2-Slokas-Girls": {
    "group": "Group 2",
    "displayName": "Sloka Chanting (Girls)",
    "eventRef": "/eventData_v2/G2-Slokas-Girls",
    "judges": [
      "Srividhya Ramesh (ATP Alumna + BV Guru)",
      "S Priya (ATP Alumna + DEC, Kanchi North)"
    ]
  },

  "G2-Vedam-Boys": {
    "group": "Group 2",
    "displayName": "Vedam (Boys)",
    "eventRef": "/eventData_v2/G2-Vedam-Boys",
    "judges": [
      "Saravanan",
      "Ramani (School Alumna)"
    ]
  },

  "G2-Vedam-Girls": {
    "group": "Group 2",
    "displayName": "Vedam (Girls)",
    "eventRef": "/eventData_v2/G2-Vedam-Girls",
    "judges": [
      "Vijayaraghavan V",
      "V Sunandi (ATP Alumna)"
    ]
  },

  "G2-Tamizhchants-Boys": {
    "group": "Group 2",
    "displayName": "Tamizh Chants (Boys)",
    "eventRef": "/eventData_v2/G2-Tamizhchants-Boys",
    "judges": [
      "Ganapathi (TNS Spiritual Coordinator)",
      "Jayashree B (ATP Alumna)"
    ]
  },

  "G2-Tamizhchants-Girls": {
    "group": "Group 2",
    "displayName": "Tamizh Chants (Girls)",
    "eventRef": "/eventData_v2/G2-Tamizhchants-Girls",
    "judges": [
      "Rajagopal (TNN Spiritual Coordinator)",
      "Sai Vijaya Deepa (ATP Alumna)"
    ]
  },

  "G2-Elocution-English": {
    "group": "Group 2",
    "displayName": "Elocution (English)",
    "eventRef": "/eventData_v2/G2-Elocution-English",
    "judges": [
      "Upendra Sai",
      "Sai Skandaa",
      "Subhashini (ATP Alumna)"
    ]
  },

  "G2-Elocution-Tamil": {
    "group": "Group 2",
    "displayName": "Elocution (Tamil)",
    "eventRef": "/eventData_v2/G2-Elocution-Tamil",
    "judges": [
      "Sai Mahesh",
      "Arthi C (ATP Alumna)",
      "Bhuvaneswari R (ATP Alumna)"
    ]
  },

  "G2-Drawing": {
    "group": "Group 2",
    "displayName": "Drawing",
    "eventRef": "/eventData_v2/G2-Drawing",
    "judges": [
      "Anuradha Govindarajan (ATP Alumna)",
      "Sasirekha Raghuram (ATP Alumna)",
      "Sai Krishna"
    ]
  },

  "G3-Bhajans-Boys": {
    "group": "Group 3",
    "displayName": "Bhajan (Boys)",
    "eventRef": "/eventData_v2/G3-Bhajans-Boys",
    "judges": [
      "Sai Prasad (Erode)",
      "Upanisha (ATP Alumna + BV Guru)"
    ]
  },

  "G3-Bhajans-Girls": {
    "group": "Group 3",
    "displayName": "Bhajan (Girls)",
    "eventRef": "/eventData_v2/G3-Bhajans-Girls",
    "judges": [
      "Sai Bhavani (TNS Vedam Incharge)",
      "Keertana (Sundaram Bhajan Coord)"
    ]
  },

  "G3-Slokas-Boys": {
    "group": "Group 3",
    "displayName": "Sloka Chanting (Boys)",
    "eventRef": "/eventData_v2/G3-Slokas-Boys",
    "judges": [
      "Shyam Kumar",
      "Srividhya V (ATP Alumna + BV Guru)",
      "Ranjani Subhash (ATP Alumna + BV Guru)"
    ]
  },

  "G3-Slokas-Girls": {
    "group": "Group 3",
    "displayName": "Sloka Chanting (Girls)",
    "eventRef": "/eventData_v2/G3-Slokas-Girls",
    "judges": [
      "Dr. Ramadevi (TNS SEC)",
      "Dr. Vijayalakshmi"
    ]
  },

  "G3-Vedam-Boys": {
    "group": "Group 3",
    "displayName": "Vedam (Boys)",
    "eventRef": "/eventData_v2/G3-Vedam-Boys",
    "judges": [
      "Srinath",
      "Padmapriya (ATP Alumna + BV Guru)"
    ]
  },

  "G3-Vedam-Girls": {
    "group": "Group 3",
    "displayName": "Vedam (Girls)",
    "eventRef": "/eventData_v2/G3-Vedam-Girls",
    "judges": [
      "Sriram G",
      "Geetha Rajharam (ATP Alumna)"
    ]
  },

  "G3-Tamizhchants-Boys": {
    "group": "Group 3",
    "displayName": "Tamizh Chants (Boys)",
    "eventRef": "/eventData_v2/G3-Tamizhchants-Boys",
    "judges": [
      "RS Manorama (ATP Alumna + BV Guru)",
      "Rangarajan"
    ]
  },

  "G3-Tamizhchants-Girls": {
    "group": "Group 3",
    "displayName": "Tamizh Chants (Girls)",
    "eventRef": "/eventData_v2/G3-Tamizhchants-Girls",
    "judges": [
      "Anusha V (ATP Alumna)",
      "Geetha (TNS Service Coordinator)"
    ]
  },

  "G3-Elocution-English": {
    "group": "Group 3",
    "displayName": "Elocution (English)",
    "eventRef": "/eventData_v2/G3-Elocution-English",
    "judges": [
      "Shyam (Ramakrishnan)",
      "Shalini Niranjan (ATP Alumna)",
      "Geethalatha (ATP Alumna + DEC Of Pondicherry)"
    ]
  },

  "G3-Elocution-Tamil": {
    "group": "Group 3",
    "displayName": "Elocution (Tamil)",
    "eventRef": "/eventData_v2/G3-Elocution-Tamil",
    "judges": [
      "Srinivasan Rajagopal",
      "Amrutha Veena",
      "S Sugasri (ATP Alumna)"
    ]
  },

  "G3-Drawing": {
    "group": "Group 3",
    "displayName": "Drawing",
    "eventRef": "/eventData_v2/G3-Drawing",
    "judges": [
      "Prashanthi",
      "Deepa R (ATP Alumna)",
      "Sathya Anantharaj (ATP Alumna)"
    ]
  },

  "GROUP-Altar-Decoration-Boys": {
    "group": "Common",
    "displayName": "Altar Decoration (Boys)",
    "eventRef": "/eventData_v2/GROUP-Altar-Decoration-Boys",
    "judges": [
      "Ravichandran",
      "Srivalli (ATP Alumna)",
      "Srividhya Ravikumar (ATP Alumna)"
    ]
  },

  "GROUP-Altar-Decoration-Girls": {
    "group": "Common",
    "displayName": "Altar Decoration (Girls)",
    "eventRef": "/eventData_v2/GROUP-Altar-Decoration-Girls",
    "judges": [
      "Jayanthi DM (ATP Alumna)",
      "Kalyani Sivakumar (ATP Alumna)",
      "Shanthi Annamalai (ATP Alumna)"
    ]
  },

  "GROUP-Devotional-Singing-Boys": {
    "group": "Common",
    "displayName": "Devotional Singing (Boys)",
    "eventRef": "/eventData_v2/GROUP-Devotional-Singing-Boys",
    "judges": [
      "Shankarasubramaniam",
      "Ranjani Babu (ATP Alumna)"
    ]
  },

  "GROUP-Devotional-Singing-Girls": {
    "group": "Common",
    "displayName": "Devotional Singing (Girls)",
    "eventRef": "/eventData_v2/GROUP-Devotional-Singing-Girls",
    "judges": [
      "Sathyapriya (ATP Alumna)",
      "Vidyashankar (TNS IT Incharge)",
      "Vinod Venkat"
    ]
  },

  "GROUP-Namakam-Chanting-Boys": {
    "group": "Common",
    "displayName": "Namakam (Boys)",
    "eventRef": "/eventData_v2/GROUP-Namakam-Boys",
    "judges": [
      "Pandurangan",
      "T R Varalakshmi (ATP Alumna)",
      "Sathyanarayanan"
    ]
  },

  "GROUP-Namakam-Chanting-Girls": {
    "group": "Common",
    "displayName": "Namakam (Girls)",
    "eventRef": "/eventData_v2/GROUP-Namakam-Girls",
    "judges": [
      "Prashant R",
      "Uttara Raghunathan (TNN SEC)",
      "Padma Sameer (ATP Alumna)"
    ]
  },

  "G3-Quiz": {
    "group": "Common",
    "displayName": "Quiz (Group 3)",
    "eventRef": "/eventData_v2/G3-Quiz",
    "judges": [
      "Gayatri Venkat",
      "Lalitha A (ATP Alumna + BV Guru)",
      "Srividhya Uppili (ATP Alumna)"
    ]
  },

  "G4-Quiz": {
    "group": "Common",
    "displayName": "Quiz (Group 4)",
    "eventRef": "/eventData_v2/G4-Quiz",
    "judges": [
      "Sudha Shyam",
      "Manjula Bhatt (ATP Alumna)",
      "Deepa Rajesh (ATP Alumna)"
    ]
  }

}


from google.cloud import firestore
db = firestore.Client()

for event_code, data in EVENT_JUDGE_MAPPING.items():
    judge_order = [
        {"order": idx + 1, "name": name}
        for idx, name in enumerate(data["judges"])
    ]

    db.collection("eventJudgeMapping").document(event_code).set({
        "eventCode": event_code,
        "group": data["group"],
        "displayName": data["displayName"],
        "eventRef": data["eventRef"],
        "expectedJudgeCount": len(judge_order),
        "judgeOrder": judge_order
    })

print("✅ eventJudgeMapping created")
